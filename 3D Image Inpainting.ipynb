# %% [markdown]
# 3D Inpainting

# %%
"""
UPLOAD PHOTO TO /3d-photo-inpainting-master/image/

 **The results are stored in the following directories**
  - Corresponding depth map estimated by [MiDaS](https://github.com/intel-isl/MiDaS.git) 
      - E.g. ```/content/3d-photo-inpainting/depth/moon.npy```
  - Inpainted 3D mesh
      - E.g. ```/content/3d-photo-inpainting/mesh/moon.ply```
  
  These 3 are to be returned
  - Rendered videos with zoom-in motion
      - E.g. ```/content/3d-photo-inpainting/video/moon_zoom-in.mp4```
  - Rendered videos with swing motion
      - E.g. ```/content/3d-photo-inpainting/video/moon_swing.mp4```
  - Rendered videos with circle motion
      - E.g. ```/content/3d-photo-inpainting/video/moon_circle.mp4```
  
    ![](https://drive.google.com/uc?id=1xBiZAeGfhsoAsG08N5UM8-f993p0G5HF)

"""


# !pip3 install torch==1.4.0+cu100 torchvision==0.5.0+cu100 -f https://download.pytorch.org/whl/torch_stable.html
# !pip3 install opencv-python==4.2.0.32
# !pip3 install vispy==0.6.4
# !pip3 install moviepy==1.0.2
# !pip3 install transforms3d==0.3.1
# !pip3 install networkx==2.3
# !sudo apt install sed

"""- **Download script and pretrained model**

"""

# Commented out IPython magic to ensure Python compatibility.
# %cd /content/
# !git clone https://github.com/vt-vl-lab/3d-photo-inpainting.git
# %cd 3d-photo-inpainting
# !sh download.sh

"""- **Switch off off-screen rendering**"""

# !sed -i 's/offscreen_rendering: True/offscreen_rendering: False/g' argument.yml

"""- **Please upload `.jpg` files to `/content/3d-photo-inpainting-master/image/`**
  - You can run this step multiple times to upload multiple `.jpg` files.
"""

# Commented out IPython magic to ensure Python compatibility.
# %cd image
# from google.colab import files
# uploaded = files.upload()
# for fn in uploaded.keys():
#   print('User uploaded file "{name}" with length {length} bytes'.format(
#       name=fn, length=len(uploaded[fn])))
# %cd ..

"""- **Execute the 3D Photo Inpainting**
  - Note: The 3D photo generation process usually takes about 2-3 minutes or more depending on the available computing resources.
"""

# !python main.py --config argument.yml

"""- **The results are stored in the following directories**
  - Corresponding depth map estimated by [MiDaS](https://github.com/intel-isl/MiDaS.git) 
      - E.g. ```/content/3d-photo-inpainting/depth/moon.npy```
  - Inpainted 3D mesh
      - E.g. ```/content/3d-photo-inpainting/mesh/moon.ply```
  
  These 3 are to be returned
  - Rendered videos with zoom-in motion
      - E.g. ```/content/3d-photo-inpainting/video/moon_zoom-in.mp4```
  - Rendered videos with swing motion
      - E.g. ```/content/3d-photo-inpainting/video/moon_swing.mp4```
  - Rendered videos with circle motion
      - E.g. ```/content/3d-photo-inpainting/video/moon_circle.mp4```
  
    ![](https://drive.google.com/uc?id=1xBiZAeGfhsoAsG08N5UM8-f993p0G5HF)
"""
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.4.0+cu100
#   Downloading https://download.pytorch.org/whl/cu100/torch-1.4.0%2Bcu100-cp37-cp37m-linux_x86_64.whl (723.9MB)
#      |████████████████████████████████| 723.9MB 26kB/s
# Collecting torchvision==0.5.0+cu100
#   Downloading https://download.pytorch.org/whl/cu100/torchvision-0.5.0%2Bcu100-cp37-cp37m-linux_x86_64.whl (4.0MB)
#      |████████████████████████████████| 4.0MB 33.9MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchvision==0.5.0+cu100) (1.15.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.5.0+cu100) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision==0.5.0+cu100) (1.19.5)
# ERROR: torchtext 0.9.1 has requirement torch==1.8.1, but you'll have torch 1.4.0+cu100 which is incompatible.
# Installing collected packages: torch, torchvision
#   Found existing installation: torch 1.8.1+cu101
#     Uninstalling torch-1.8.1+cu101:
#       Successfully uninstalled torch-1.8.1+cu101
#   Found existing installation: torchvision 0.9.1+cu101
#     Uninstalling torchvision-0.9.1+cu101:
#       Successfully uninstalled torchvision-0.9.1+cu101
# Successfully installed torch-1.4.0+cu100 torchvision-0.5.0+cu100
# Collecting opencv-python==4.2.0.32
#   Downloading https://files.pythonhosted.org/packages/34/a3/403dbaef909fee9f9f6a8eaff51d44085a14e5bb1a1ff7257117d744986a/opencv_python-4.2.0.32-cp37-cp37m-manylinux1_x86_64.whl (28.2MB)
#      |████████████████████████████████| 28.2MB 109kB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python==4.2.0.32) (1.19.5)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: opencv-python
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# Successfully installed opencv-python-4.2.0.32
# Collecting vispy==0.6.4
#   Downloading https://files.pythonhosted.org/packages/5f/7e/9e24a986e8fe2ee94588f806e1c4579c8c285e7e42b70189d79db4132e07/vispy-0.6.4-cp37-cp37m-manylinux2010_x86_64.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 9.1MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from vispy==0.6.4) (1.19.5)
# Collecting freetype-py
#   Downloading https://files.pythonhosted.org/packages/40/b5/56751e13f8b4a42f52c1b85ecce1446f83245190d820b42748eb8574ae43/freetype_py-2.2.0-py3-none-manylinux1_x86_64.whl (890kB)
#      |████████████████████████████████| 890kB 51.2MB/s
# Installing collected packages: freetype-py, vispy
# Successfully installed freetype-py-2.2.0 vispy-0.6.4
# Collecting moviepy==1.0.2
#   Downloading https://files.pythonhosted.org/packages/71/64/e7f0876716d5c35612bf8e9e49299d0f491285f10f36cbb481556ab0062b/moviepy-1.0.2.tar.gz (7.8MB)
#      |████████████████████████████████| 7.9MB 6.7MB/s
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from moviepy==1.0.2) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.7/dist-packages (from moviepy==1.0.2) (4.41.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.7/dist-packages (from moviepy==1.0.2) (2.23.0)
# Collecting proglog<=1.0.0
#   Downloading https://files.pythonhosted.org/packages/fe/ab/4cb19b578e1364c0b2d6efd6521a8b4b4e5c4ae6528041d31a2a951dd991/proglog-0.1.9.tar.gz
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from moviepy==1.0.2) (1.19.5)
# Collecting imageio<3.0,>=2.5
#   Downloading https://files.pythonhosted.org/packages/6e/57/5d899fae74c1752f52869b613a8210a2480e1a69688e65df6cb26117d45d/imageio-2.9.0-py3-none-any.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 48.4MB/s
# Collecting imageio_ffmpeg>=0.2.0
#   Downloading https://files.pythonhosted.org/packages/89/0f/4b49476d185a273163fa648eaf1e7d4190661d1bbf37ec2975b84df9de02/imageio_ffmpeg-0.4.3-py3-none-manylinux2010_x86_64.whl (26.9MB)
#      |████████████████████████████████| 26.9MB 65.8MB/s
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.2) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.2) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.2) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.2) (2.10)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio<3.0,>=2.5->moviepy==1.0.2) (7.1.2)
# Building wheels for collected packages: moviepy, proglog
#   Building wheel for moviepy (setup.py) ... done
#   Created wheel for moviepy: filename=moviepy-1.0.2-cp37-none-any.whl size=110730 sha256=d2c40a55551f0f71e109b6c05f64d78f2107dc3158809bcae444dc1d5618706b
#   Stored in directory: /root/.cache/pip/wheels/20/49/a9/770a9a22e7a020d796ab3784d2dc4839e38450a1ac87e6106f
#   Building wheel for proglog (setup.py) ... done
#   Created wheel for proglog: filename=proglog-0.1.9-cp37-none-any.whl size=6148 sha256=90bb6f6b4ffa1c6d9845a8e45f0ea07ad33676086f2bdc91ea8cfda0609bbbc2
#   Stored in directory: /root/.cache/pip/wheels/65/56/60/1d0306a8d90b188af393c1812ddb502a8821b70917f82dcc00
# Successfully built moviepy proglog
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: proglog, imageio, imageio-ffmpeg, moviepy
#   Found existing installation: imageio 2.4.1
#     Uninstalling imageio-2.4.1:
#       Successfully uninstalled imageio-2.4.1
#   Found existing installation: moviepy 0.2.3.5
#     Uninstalling moviepy-0.2.3.5:
#       Successfully uninstalled moviepy-0.2.3.5
# Successfully installed imageio-2.9.0 imageio-ffmpeg-0.4.3 moviepy-1.0.2 proglog-0.1.9
# Collecting transforms3d==0.3.1
#   Downloading https://files.pythonhosted.org/packages/b5/f7/e85809168a548a854d7c1331560c27b4f5381698d29c12e57759192b2bc1/transforms3d-0.3.1.tar.gz (62kB)
#      |████████████████████████████████| 71kB 6.6MB/s
# Building wheels for collected packages: transforms3d
#   Building wheel for transforms3d (setup.py) ... done
#   Created wheel for transforms3d: filename=transforms3d-0.3.1-cp37-none-any.whl size=59374 sha256=9775595cec40f1f3dccaabf3a6211f7c014ce1882096b6a8f07e5cd22616da45
#   Stored in directory: /root/.cache/pip/wheels/3d/3c/84/28d36677f3c760c048bd02b5a547ea0c4027770cc9cdb9af1e
# Successfully built transforms3d
# Installing collected packages: transforms3d
# Successfully installed transforms3d-0.3.1
# Collecting networkx==2.3
#   Downloading https://files.pythonhosted.org/packages/85/08/f20aef11d4c343b557e5de6b9548761811eb16e438cee3d32b1c66c8566b/networkx-2.3.zip (1.7MB)
#      |████████████████████████████████| 1.8MB 9.1MB/s
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from networkx==2.3) (4.4.2)
# Building wheels for collected packages: networkx
#   Building wheel for networkx (setup.py) ... done
#   Created wheel for networkx: filename=networkx-2.3-py2.py3-none-any.whl size=1556408 sha256=35f9241cc3bca349f481d26762574df133c90e7030983a3258e119c778d81076
#   Stored in directory: /root/.cache/pip/wheels/de/63/64/3699be2a9d0ccdb37c7f16329acf3863fd76eda58c39c737af
# Successfully built networkx
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: networkx
#   Found existing installation: networkx 2.5.1
#     Uninstalling networkx-2.5.1:
#       Successfully uninstalled networkx-2.5.1
# Successfully installed networkx-2.3
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# sed is already the newest version (4.4-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# Cloning into '3d-photo-inpainting'...
# remote: Enumerating objects: 350, done.
# remote: Total 350 (delta 0), reused 0 (delta 0), pack-reused 350
# Receiving objects: 100% (350/350), 130.13 MiB | 38.24 MiB/s, done.
# Resolving deltas: 100% (192/192), done.
# /content/3d-photo-inpainting/3d-photo-inpainting
# downloading from filebox ...
# --2021-04-23 15:30:50--  https://filebox.ece.vt.edu/~jbhuang/project/3DPhoto/model/color-model.pth
# Resolving filebox.ece.vt.edu (filebox.ece.vt.edu)... 128.173.88.43
# Connecting to filebox.ece.vt.edu (filebox.ece.vt.edu)|128.173.88.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 206331633 (197M)
# Saving to: ‘color-model.pth’
#
# color-model.pth     100%[===================>] 196.77M  40.0MB/s    in 9.0s
#
# 2021-04-23 15:30:59 (21.9 MB/s) - ‘color-model.pth’ saved [206331633/206331633]
#
# --2021-04-23 15:30:59--  https://filebox.ece.vt.edu/~jbhuang/project/3DPhoto/model/depth-model.pth
# Resolving filebox.ece.vt.edu (filebox.ece.vt.edu)... 128.173.88.43
# Connecting to filebox.ece.vt.edu (filebox.ece.vt.edu)|128.173.88.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 206272258 (197M)
# Saving to: ‘depth-model.pth’
#
# depth-model.pth     100%[===================>] 196.72M  42.2MB/s    in 8.8s
#
# 2021-04-23 15:31:08 (22.3 MB/s) - ‘depth-model.pth’ saved [206272258/206272258]
#
# --2021-04-23 15:31:08--  https://filebox.ece.vt.edu/~jbhuang/project/3DPhoto/model/edge-model.pth
# Resolving filebox.ece.vt.edu (filebox.ece.vt.edu)... 128.173.88.43
# Connecting to filebox.ece.vt.edu (filebox.ece.vt.edu)|128.173.88.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45974122 (44M)
# Saving to: ‘edge-model.pth’
#
# edge-model.pth      100%[===================>]  43.84M  11.1MB/s    in 5.9s
#
# 2021-04-23 15:31:14 (7.49 MB/s) - ‘edge-model.pth’ saved [45974122/45974122]
#
# --2021-04-23 15:31:14--  https://filebox.ece.vt.edu/~jbhuang/project/3DPhoto/model/model.pt
# Resolving filebox.ece.vt.edu (filebox.ece.vt.edu)... 128.173.88.43
# Connecting to filebox.ece.vt.edu (filebox.ece.vt.edu)|128.173.88.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149751722 (143M)
# Saving to: ‘model.pt’
#
# model.pt            100%[===================>] 142.81M  36.6MB/s    in 8.2s
#
# 2021-04-23 15:31:23 (17.5 MB/s) - ‘model.pt’ saved [149751722/149751722]
#
# running on device 0
#   0% 0/1 [00:00<?, ?it/s]Current Source ==>  moon
# Running depth extraction at 1619191886.5479417
# initialize
# device: cpu
# start processing
#   processing image/moon.jpg (1/1)
# torch.Size([1, 3, 384, 384])
# finished
# Start Running 3D_Photo ...
# Loading edge model at 1619191900.972524
# Loading depth model at 1619191903.5303545
# Loading rgb model at 1619191904.2726715
# Writing depth ply (and basically doing everything) at 1619191904.9382567
# Writing mesh file mesh/moon.ply ...
# Making video at 1619192073.668795
# fov: 53.13010235415598
# Moviepy - Building video video/moon_dolly-zoom-in.mp4.
# Moviepy - Writing video video/moon_dolly-zoom-in.mp4
#
#   0% 0/1 [03:44<?, ?it/s]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   1% 2/241 [00:00<00:37,  6.45it/s, now=None]
# t:   1% 3/241 [00:00<00:34,  6.84it/s, now=None]
# t:   6% 15/241 [00:00<00:23,  9.53it/s, now=None]
# t:  12% 28/241 [00:00<00:16, 13.16it/s, now=None]
# t:  17% 41/241 [00:00<00:11, 17.99it/s, now=None]
# t:  21% 50/241 [00:01<00:09, 19.67it/s, now=None]
# t:  24% 57/241 [00:01<00:08, 22.23it/s, now=None]
# t:  26% 63/241 [00:01<00:07, 23.52it/s, now=None]
# t:  28% 68/241 [00:01<00:06, 25.68it/s, now=None]
# t:  30% 73/241 [00:01<00:06, 26.78it/s, now=None]
# t:  32% 77/241 [00:02<00:06, 25.89it/s, now=None]
# t:  34% 81/241 [00:02<00:05, 27.44it/s, now=None]
# t:  35% 85/241 [00:02<00:05, 26.73it/s, now=None]
# t:  37% 89/241 [00:02<00:05, 28.23it/s, now=None]
# t:  39% 93/241 [00:02<00:05, 29.11it/s, now=None]
# t:  40% 97/241 [00:02<00:04, 29.26it/s, now=None]
# t:  42% 101/241 [00:02<00:05, 27.92it/s, now=None]
# t:  43% 104/241 [00:02<00:04, 27.86it/s, now=None]
# t:  44% 107/241 [00:03<00:05, 26.31it/s, now=None]
# t:  46% 111/241 [00:03<00:04, 26.66it/s, now=None]
# t:  48% 115/241 [00:03<00:04, 27.34it/s, now=None]
# t:  49% 119/241 [00:03<00:04, 27.65it/s, now=None]
# t:  51% 123/241 [00:03<00:04, 27.83it/s, now=None]
# t:  53% 127/241 [00:03<00:04, 27.97it/s, now=None]
# t:  54% 131/241 [00:03<00:03, 27.87it/s, now=None]
# t:  56% 134/241 [00:04<00:03, 26.81it/s, now=None]
# t:  57% 138/241 [00:04<00:03, 29.57it/s, now=None]
# t:  59% 142/241 [00:04<00:03, 29.26it/s, now=None]
# t:  60% 145/241 [00:04<00:03, 28.86it/s, now=None]
# t:  61% 148/241 [00:04<00:03, 26.85it/s, now=None]
# t:  63% 151/241 [00:04<00:03, 25.77it/s, now=None]
# t:  64% 155/241 [00:04<00:03, 26.47it/s, now=None]
# t:  66% 159/241 [00:04<00:03, 26.30it/s, now=None]
# t:  68% 163/241 [00:05<00:02, 26.71it/s, now=None]
# t:  69% 167/241 [00:05<00:02, 26.22it/s, now=None]
# t:  71% 171/241 [00:05<00:02, 26.90it/s, now=None]
# t:  73% 175/241 [00:05<00:02, 27.57it/s, now=None]
# t:  74% 179/241 [00:05<00:02, 27.35it/s, now=None]
# t:  76% 183/241 [00:05<00:02, 27.75it/s, now=None]
# t:  78% 187/241 [00:06<00:01, 27.46it/s, now=None]
# t:  79% 191/241 [00:06<00:01, 27.52it/s, now=None]
# t:  81% 195/241 [00:06<00:01, 27.39it/s, now=None]
# t:  83% 199/241 [00:06<00:01, 27.48it/s, now=None]
# t:  84% 203/241 [00:06<00:01, 27.70it/s, now=None]
# t:  86% 207/241 [00:06<00:01, 27.53it/s, now=None]
# t:  88% 211/241 [00:06<00:01, 27.18it/s, now=None]
# t:  89% 215/241 [00:07<00:00, 26.70it/s, now=None]
# t:  91% 219/241 [00:07<00:00, 26.64it/s, now=None]
# t:  93% 223/241 [00:07<00:00, 26.83it/s, now=None]
# t:  94% 227/241 [00:07<00:00, 27.34it/s, now=None]
# t:  96% 231/241 [00:07<00:00, 27.38it/s, now=None]
# t:  98% 235/241 [00:07<00:00, 27.37it/s, now=None]
# t:  99% 239/241 [00:07<00:00, 27.04it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/moon_dolly-zoom-in.mp4
# Moviepy - Building video video/moon_zoom-in.mp4.
# Moviepy - Writing video video/moon_zoom-in.mp4
#
#   0% 0/1 [04:26<?, ?it/s]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   5% 11/241 [00:00<00:02, 105.62it/s, now=None]
# t:  10% 25/241 [00:00<00:01, 111.03it/s, now=None]
# t:  16% 38/241 [00:00<00:01, 114.91it/s, now=None]
# t:  20% 48/241 [00:00<00:02, 73.88it/s, now=None]
# t:  23% 55/241 [00:00<00:03, 46.69it/s, now=None]
# t:  25% 61/241 [00:01<00:04, 39.50it/s, now=None]
# t:  27% 66/241 [00:01<00:05, 34.93it/s, now=None]
# t:  29% 71/241 [00:01<00:05, 28.94it/s, now=None]
# t:  31% 75/241 [00:01<00:05, 27.85it/s, now=None]
# t:  33% 79/241 [00:01<00:05, 27.32it/s, now=None]
# t:  34% 83/241 [00:01<00:05, 27.19it/s, now=None]
# t:  36% 87/241 [00:02<00:05, 26.39it/s, now=None]
# t:  38% 91/241 [00:02<00:05, 26.22it/s, now=None]
# t:  39% 95/241 [00:02<00:05, 25.99it/s, now=None]
# t:  41% 99/241 [00:02<00:05, 25.83it/s, now=None]
# t:  43% 103/241 [00:02<00:05, 25.86it/s, now=None]
# t:  44% 107/241 [00:02<00:05, 25.96it/s, now=None]
# t:  46% 111/241 [00:03<00:05, 25.37it/s, now=None]
# t:  47% 114/241 [00:03<00:05, 24.94it/s, now=None]
# t:  49% 118/241 [00:03<00:04, 27.09it/s, now=None]
# t:  50% 121/241 [00:03<00:04, 25.96it/s, now=None]
# t:  51% 124/241 [00:03<00:04, 24.56it/s, now=None]
# t:  53% 127/241 [00:03<00:04, 23.64it/s, now=None]
# t:  54% 131/241 [00:03<00:04, 24.05it/s, now=None]
# t:  56% 135/241 [00:04<00:04, 23.62it/s, now=None]
# t:  58% 139/241 [00:04<00:04, 23.73it/s, now=None]
# t:  59% 143/241 [00:04<00:04, 23.68it/s, now=None]
# t:  61% 147/241 [00:04<00:03, 23.84it/s, now=None]
# t:  63% 151/241 [00:04<00:03, 24.27it/s, now=None]
# t:  64% 155/241 [00:04<00:03, 24.60it/s, now=None]
# t:  66% 159/241 [00:04<00:03, 24.90it/s, now=None]
# t:  68% 163/241 [00:05<00:03, 24.34it/s, now=None]
# t:  69% 167/241 [00:05<00:03, 24.15it/s, now=None]
# t:  71% 170/241 [00:05<00:02, 24.71it/s, now=None]
# t:  72% 174/241 [00:05<00:02, 27.66it/s, now=None]
# t:  73% 177/241 [00:05<00:02, 26.33it/s, now=None]
# t:  75% 180/241 [00:05<00:02, 23.68it/s, now=None]
# t:  76% 183/241 [00:05<00:02, 22.95it/s, now=None]
# t:  78% 187/241 [00:06<00:02, 23.21it/s, now=None]
# t:  79% 191/241 [00:06<00:02, 23.77it/s, now=None]
# t:  81% 195/241 [00:06<00:01, 23.69it/s, now=None]
# t:  83% 199/241 [00:06<00:01, 23.88it/s, now=None]
# t:  84% 203/241 [00:06<00:01, 23.93it/s, now=None]
# t:  86% 207/241 [00:06<00:01, 24.36it/s, now=None]
# t:  88% 211/241 [00:07<00:01, 24.28it/s, now=None]
# t:  89% 215/241 [00:07<00:01, 24.25it/s, now=None]
# t:  91% 219/241 [00:07<00:00, 24.00it/s, now=None]
# t:  93% 223/241 [00:07<00:00, 24.27it/s, now=None]
# t:  94% 227/241 [00:07<00:00, 24.18it/s, now=None]
# t:  96% 231/241 [00:07<00:00, 24.72it/s, now=None]
# t:  97% 234/241 [00:08<00:00, 24.70it/s, now=None]
# t:  99% 238/241 [00:08<00:00, 25.67it/s, now=None]
# t: 100% 241/241 [00:08<00:00, 25.95it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/moon_zoom-in.mp4
# Moviepy - Building video video/moon_circle.mp4.
# Moviepy - Writing video video/moon_circle.mp4
#
#   0% 0/1 [05:09<?, ?it/s]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   5% 12/241 [00:00<00:02, 110.51it/s, now=None]
# t:   9% 22/241 [00:00<00:02, 104.41it/s, now=None]
# t:  13% 31/241 [00:00<00:02, 98.68it/s, now=None]
# t:  17% 42/241 [00:00<00:02, 98.42it/s, now=None]
# t:  21% 50/241 [00:00<00:04, 44.45it/s, now=None]
# t:  23% 56/241 [00:01<00:05, 35.68it/s, now=None]
# t:  25% 61/241 [00:01<00:05, 32.45it/s, now=None]
# t:  27% 66/241 [00:01<00:06, 28.91it/s, now=None]
# t:  29% 70/241 [00:01<00:06, 27.95it/s, now=None]
# t:  31% 74/241 [00:01<00:06, 26.02it/s, now=None]
# t:  32% 77/241 [00:01<00:06, 25.76it/s, now=None]
# t:  33% 80/241 [00:02<00:07, 22.99it/s, now=None]
# t:  34% 83/241 [00:02<00:07, 22.27it/s, now=None]
# t:  36% 86/241 [00:02<00:06, 23.76it/s, now=None]
# t:  37% 89/241 [00:02<00:06, 23.86it/s, now=None]
# t:  38% 92/241 [00:02<00:06, 21.44it/s, now=None]
# t:  39% 95/241 [00:02<00:06, 21.15it/s, now=None]
# t:  41% 98/241 [00:02<00:06, 22.99it/s, now=None]
# t:  42% 101/241 [00:03<00:05, 23.53it/s, now=None]
# t:  43% 104/241 [00:03<00:06, 21.71it/s, now=None]
# t:  44% 107/241 [00:03<00:06, 20.91it/s, now=None]
# t:  46% 111/241 [00:03<00:06, 21.11it/s, now=None]
# t:  48% 115/241 [00:03<00:05, 21.26it/s, now=None]
# t:  49% 119/241 [00:03<00:05, 21.39it/s, now=None]
# t:  51% 122/241 [00:04<00:05, 22.94it/s, now=None]
# t:  52% 125/241 [00:04<00:05, 22.00it/s, now=None]
# t:  53% 128/241 [00:04<00:05, 22.02it/s, now=None]
# t:  54% 131/241 [00:04<00:05, 21.65it/s, now=None]
# t:  56% 134/241 [00:04<00:04, 22.93it/s, now=None]
# t:  57% 137/241 [00:04<00:04, 23.64it/s, now=None]
# t:  58% 140/241 [00:04<00:04, 22.78it/s, now=None]
# t:  59% 143/241 [00:04<00:04, 21.52it/s, now=None]
# t:  61% 146/241 [00:05<00:04, 23.38it/s, now=None]
# t:  62% 149/241 [00:05<00:03, 24.35it/s, now=None]
# t:  63% 152/241 [00:05<00:03, 23.10it/s, now=None]
# t:  64% 155/241 [00:05<00:03, 22.33it/s, now=None]
# t:  66% 158/241 [00:05<00:03, 23.74it/s, now=None]
# t:  67% 161/241 [00:05<00:03, 25.04it/s, now=None]
# t:  68% 164/241 [00:05<00:03, 23.57it/s, now=None]
# t:  69% 167/241 [00:05<00:03, 22.17it/s, now=None]
# t:  71% 171/241 [00:06<00:03, 22.52it/s, now=None]
# t:  73% 175/241 [00:06<00:02, 22.35it/s, now=None]
# t:  74% 178/241 [00:06<00:02, 23.49it/s, now=None]
# t:  75% 181/241 [00:06<00:02, 21.74it/s, now=None]
# t:  76% 184/241 [00:06<00:02, 22.18it/s, now=None]
# t:  78% 187/241 [00:06<00:02, 21.35it/s, now=None]
# t:  79% 190/241 [00:07<00:02, 21.42it/s, now=None]
# t:  80% 193/241 [00:07<00:02, 22.75it/s, now=None]
# t:  81% 196/241 [00:07<00:02, 21.70it/s, now=None]
# t:  83% 199/241 [00:07<00:01, 21.18it/s, now=None]
# t:  84% 202/241 [00:07<00:01, 22.97it/s, now=None]
# t:  85% 205/241 [00:07<00:01, 22.76it/s, now=None]
# t:  86% 208/241 [00:07<00:01, 21.21it/s, now=None]
# t:  88% 211/241 [00:08<00:01, 20.77it/s, now=None]
# t:  89% 215/241 [00:08<00:01, 21.31it/s, now=None]
# t:  90% 218/241 [00:08<00:01, 22.90it/s, now=None]
# t:  92% 221/241 [00:08<00:00, 23.15it/s, now=None]
# t:  93% 224/241 [00:08<00:00, 23.04it/s, now=None]
# t:  94% 227/241 [00:08<00:00, 23.05it/s, now=None]
# t:  96% 231/241 [00:08<00:00, 22.10it/s, now=None]
# t:  98% 235/241 [00:09<00:00, 22.34it/s, now=None]
# t:  99% 238/241 [00:09<00:00, 24.09it/s, now=None]
# t: 100% 241/241 [00:09<00:00, 24.72it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/moon_circle.mp4
# Moviepy - Building video video/moon_swing.mp4.
# Moviepy - Writing video video/moon_swing.mp4
#
#   0% 0/1 [05:53<?, ?it/s]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   4% 9/241 [00:00<00:02, 85.25it/s, now=None]
# t:   9% 21/241 [00:00<00:02, 91.96it/s, now=None]
# t:  15% 35/241 [00:00<00:02, 101.06it/s, now=None]
# t:  19% 46/241 [00:00<00:01, 101.15it/s, now=None]
# t:  23% 55/241 [00:00<00:04, 46.06it/s, now=None]
# t:  26% 62/241 [00:01<00:04, 37.66it/s, now=None]
# t:  28% 68/241 [00:01<00:05, 29.71it/s, now=None]
# t:  30% 73/241 [00:01<00:08, 20.47it/s, now=None]
# t:  32% 77/241 [00:02<00:07, 21.06it/s, now=None]
# t:  34% 81/241 [00:02<00:07, 21.14it/s, now=None]
# t:  35% 84/241 [00:02<00:07, 20.26it/s, now=None]
# t:  37% 88/241 [00:02<00:07, 20.20it/s, now=None]
# t:  38% 92/241 [00:02<00:07, 20.81it/s, now=None]
# t:  40% 96/241 [00:02<00:06, 21.22it/s, now=None]
# t:  41% 100/241 [00:03<00:06, 21.33it/s, now=None]
# t:  43% 104/241 [00:03<00:06, 21.08it/s, now=None]
# t:  45% 108/241 [00:03<00:06, 21.62it/s, now=None]
# t:  46% 111/241 [00:03<00:05, 22.82it/s, now=None]
# t:  47% 114/241 [00:03<00:05, 22.11it/s, now=None]
# t:  49% 117/241 [00:03<00:05, 23.08it/s, now=None]
# t:  50% 120/241 [00:04<00:05, 21.76it/s, now=None]
# t:  51% 124/241 [00:04<00:05, 22.20it/s, now=None]
# t:  53% 128/241 [00:04<00:05, 22.05it/s, now=None]
# t:  55% 132/241 [00:04<00:04, 22.19it/s, now=None]
# t:  56% 135/241 [00:04<00:04, 23.81it/s, now=None]
# t:  57% 138/241 [00:04<00:04, 23.89it/s, now=None]
# t:  59% 141/241 [00:04<00:04, 22.35it/s, now=None]
# t:  60% 144/241 [00:05<00:04, 21.50it/s, now=None]
# t:  61% 148/241 [00:05<00:04, 21.40it/s, now=None]
# t:  63% 151/241 [00:05<00:03, 22.83it/s, now=None]
# t:  64% 155/241 [00:05<00:03, 24.15it/s, now=None]
# t:  66% 158/241 [00:05<00:03, 22.23it/s, now=None]
# t:  67% 161/241 [00:05<00:03, 23.37it/s, now=None]
# t:  68% 164/241 [00:05<00:03, 23.16it/s, now=None]
# t:  69% 167/241 [00:06<00:03, 24.41it/s, now=None]
# t:  71% 171/241 [00:06<00:02, 25.71it/s, now=None]
# t:  73% 175/241 [00:06<00:02, 24.39it/s, now=None]
# t:  74% 178/241 [00:06<00:02, 24.91it/s, now=None]
# t:  75% 181/241 [00:06<00:02, 25.40it/s, now=None]
# t:  76% 184/241 [00:06<00:02, 23.83it/s, now=None]
# t:  78% 188/241 [00:06<00:02, 23.61it/s, now=None]
# t:  79% 191/241 [00:07<00:02, 24.08it/s, now=None]
# t:  80% 194/241 [00:07<00:02, 21.85it/s, now=None]
# t:  82% 197/241 [00:07<00:01, 23.07it/s, now=None]
# t:  83% 200/241 [00:07<00:01, 21.40it/s, now=None]
# t:  85% 204/241 [00:07<00:01, 21.21it/s, now=None]
# t:  86% 208/241 [00:07<00:01, 21.62it/s, now=None]
# t:  88% 212/241 [00:08<00:01, 21.80it/s, now=None]
# t:  90% 216/241 [00:08<00:01, 21.67it/s, now=None]
# t:  91% 220/241 [00:08<00:00, 21.39it/s, now=None]
# t:  93% 224/241 [00:08<00:00, 21.62it/s, now=None]
# t:  95% 228/241 [00:08<00:00, 21.88it/s, now=None]
# t:  96% 232/241 [00:08<00:00, 22.07it/s, now=None]
# t:  98% 235/241 [00:09<00:00, 23.51it/s, now=None]
# t:  99% 238/241 [00:09<00:00, 22.55it/s, now=None]
# t: 100% 241/241 [00:09<00:00, 21.39it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/moon_swing.mp4
# 100% 1/1 [06:04<00:00, 364.98s/it]
# '- **The results are stored in the following directories**\n  - Corresponding depth map estimated by [MiDaS](https://github.com/intel-isl/MiDaS.git) \n      - E.g. ```/content/3d-photo-inpainting/depth/moon.npy```\n  - Inpainted 3D mesh\n      - E.g. ```/content/3d-photo-inpainting/mesh/moon.ply```\n  \n  These 3 are to be returned\n  - Rendered videos with zoom-in motion\n      - E.g. ```/content/3d-photo-inpainting/video/moon_zoom-in.mp4```\n  - Rendered videos with swing motion\n      - E.g. ```/content/3d-photo-inpainting/video/moon_swing.mp4```\n  - Rendered videos with circle motion\n      - E.g. ```/content/3d-photo-inpainting/video/moon_circle.mp4```\n  \n    ![](https://drive.google.com/uc?id=1xBiZAeGfhsoAsG08N5UM8-f993p0G5HF)\n'

# %% [markdown]
# - **Prepare environment**

# %%
# !pip3 install torch==1.4.0+cu100 torchvision==0.5.0+cu100 -f https://download.pytorch.org/whl/torch_stable.html
# !pip3 install opencv-python==4.2.0.32
# !pip3 install vispy==0.6.4
# !pip3 install moviepy==1.0.2
# !pip3 install transforms3d==0.3.1
# !pip3 install networkx==2.3
# !sudo apt install sed
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.4.0+cu100
#   Downloading https://download.pytorch.org/whl/cu100/torch-1.4.0%2Bcu100-cp37-cp37m-linux_x86_64.whl (723.9MB)
#      |████████████████████████████████| 723.9MB 24kB/s
# Collecting torchvision==0.5.0+cu100
#   Downloading https://download.pytorch.org/whl/cu100/torchvision-0.5.0%2Bcu100-cp37-cp37m-linux_x86_64.whl (4.0MB)
#      |████████████████████████████████| 4.0MB 31.0MB/s
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.5.0+cu100) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchvision==0.5.0+cu100) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision==0.5.0+cu100) (1.19.5)
# ERROR: torchtext 0.9.1 has requirement torch==1.8.1, but you'll have torch 1.4.0+cu100 which is incompatible.
# Installing collected packages: torch, torchvision
#   Found existing installation: torch 1.8.1+cu101
#     Uninstalling torch-1.8.1+cu101:
#       Successfully uninstalled torch-1.8.1+cu101
#   Found existing installation: torchvision 0.9.1+cu101
#     Uninstalling torchvision-0.9.1+cu101:
#       Successfully uninstalled torchvision-0.9.1+cu101
# Successfully installed torch-1.4.0+cu100 torchvision-0.5.0+cu100
# Collecting opencv-python==4.2.0.32
#   Downloading https://files.pythonhosted.org/packages/34/a3/403dbaef909fee9f9f6a8eaff51d44085a14e5bb1a1ff7257117d744986a/opencv_python-4.2.0.32-cp37-cp37m-manylinux1_x86_64.whl (28.2MB)
#      |████████████████████████████████| 28.2MB 99kB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python==4.2.0.32) (1.19.5)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: opencv-python
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# Successfully installed opencv-python-4.2.0.32
# Collecting vispy==0.6.4
#   Downloading https://files.pythonhosted.org/packages/5f/7e/9e24a986e8fe2ee94588f806e1c4579c8c285e7e42b70189d79db4132e07/vispy-0.6.4-cp37-cp37m-manylinux2010_x86_64.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 4.3MB/s
# Collecting freetype-py
#   Downloading https://files.pythonhosted.org/packages/40/b5/56751e13f8b4a42f52c1b85ecce1446f83245190d820b42748eb8574ae43/freetype_py-2.2.0-py3-none-manylinux1_x86_64.whl (890kB)
#      |████████████████████████████████| 890kB 37.7MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from vispy==0.6.4) (1.19.5)
# Installing collected packages: freetype-py, vispy
# Successfully installed freetype-py-2.2.0 vispy-0.6.4
# Collecting moviepy==1.0.2
#   Downloading https://files.pythonhosted.org/packages/71/64/e7f0876716d5c35612bf8e9e49299d0f491285f10f36cbb481556ab0062b/moviepy-1.0.2.tar.gz (7.8MB)
#      |████████████████████████████████| 7.9MB 3.6MB/s
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from moviepy==1.0.2) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.7/dist-packages (from moviepy==1.0.2) (4.41.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.7/dist-packages (from moviepy==1.0.2) (2.23.0)
# Collecting proglog<=1.0.0
#   Downloading https://files.pythonhosted.org/packages/fe/ab/4cb19b578e1364c0b2d6efd6521a8b4b4e5c4ae6528041d31a2a951dd991/proglog-0.1.9.tar.gz
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from moviepy==1.0.2) (1.19.5)
# Collecting imageio<3.0,>=2.5
#   Downloading https://files.pythonhosted.org/packages/6e/57/5d899fae74c1752f52869b613a8210a2480e1a69688e65df6cb26117d45d/imageio-2.9.0-py3-none-any.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 35.5MB/s
# Collecting imageio_ffmpeg>=0.2.0
#   Downloading https://files.pythonhosted.org/packages/89/0f/4b49476d185a273163fa648eaf1e7d4190661d1bbf37ec2975b84df9de02/imageio_ffmpeg-0.4.3-py3-none-manylinux2010_x86_64.whl (26.9MB)
#      |████████████████████████████████| 26.9MB 113kB/s
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.2) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.2) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.2) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.2) (1.24.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio<3.0,>=2.5->moviepy==1.0.2) (7.1.2)
# Building wheels for collected packages: moviepy, proglog
#   Building wheel for moviepy (setup.py) ... done
#   Created wheel for moviepy: filename=moviepy-1.0.2-cp37-none-any.whl size=110730 sha256=20f28ba886207702e4310ab8db0219a8ff018eb1d12c3ee9ecb12b1cf453c63d
#   Stored in directory: /root/.cache/pip/wheels/20/49/a9/770a9a22e7a020d796ab3784d2dc4839e38450a1ac87e6106f
#   Building wheel for proglog (setup.py) ... done
#   Created wheel for proglog: filename=proglog-0.1.9-cp37-none-any.whl size=6148 sha256=02c37c6655c1acf9a61942271acd520627be5e8b0e12473bd28ee7713f56040b
#   Stored in directory: /root/.cache/pip/wheels/65/56/60/1d0306a8d90b188af393c1812ddb502a8821b70917f82dcc00
# Successfully built moviepy proglog
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: proglog, imageio, imageio-ffmpeg, moviepy
#   Found existing installation: imageio 2.4.1
#     Uninstalling imageio-2.4.1:
#       Successfully uninstalled imageio-2.4.1
#   Found existing installation: moviepy 0.2.3.5
#     Uninstalling moviepy-0.2.3.5:
#       Successfully uninstalled moviepy-0.2.3.5
# Successfully installed imageio-2.9.0 imageio-ffmpeg-0.4.3 moviepy-1.0.2 proglog-0.1.9
# Collecting transforms3d==0.3.1
#   Downloading https://files.pythonhosted.org/packages/b5/f7/e85809168a548a854d7c1331560c27b4f5381698d29c12e57759192b2bc1/transforms3d-0.3.1.tar.gz (62kB)
#      |████████████████████████████████| 71kB 3.3MB/s
# Building wheels for collected packages: transforms3d
#   Building wheel for transforms3d (setup.py) ... done
#   Created wheel for transforms3d: filename=transforms3d-0.3.1-cp37-none-any.whl size=59374 sha256=0c1100513652f26c89078dd4d1d47a0341ee5c57684fffd0d69fc00958c90912
#   Stored in directory: /root/.cache/pip/wheels/3d/3c/84/28d36677f3c760c048bd02b5a547ea0c4027770cc9cdb9af1e
# Successfully built transforms3d
# Installing collected packages: transforms3d
# Successfully installed transforms3d-0.3.1
# Collecting networkx==2.3
#   Downloading https://files.pythonhosted.org/packages/85/08/f20aef11d4c343b557e5de6b9548761811eb16e438cee3d32b1c66c8566b/networkx-2.3.zip (1.7MB)
#      |████████████████████████████████| 1.8MB 4.1MB/s
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from networkx==2.3) (4.4.2)
# Building wheels for collected packages: networkx
#   Building wheel for networkx (setup.py) ... done
#   Created wheel for networkx: filename=networkx-2.3-py2.py3-none-any.whl size=1556408 sha256=5b80f47d3be2256a5ad582f3aab0353675562986633009a40098066c374e5490
#   Stored in directory: /root/.cache/pip/wheels/de/63/64/3699be2a9d0ccdb37c7f16329acf3863fd76eda58c39c737af
# Successfully built networkx
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: networkx
#   Found existing installation: networkx 2.5
#     Uninstalling networkx-2.5:
#       Successfully uninstalled networkx-2.5
# Successfully installed networkx-2.3
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# sed is already the newest version (4.4-2).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.

# %% [markdown]
# - **Download script and pretrained model**

# %%
# %cd /content/
# !git clone https://github.com/vt-vl-lab/3d-photo-inpainting.git
# %cd 3d-photo-inpainting
# !sh download.sh
# Out:
# /content
# Cloning into '3d-photo-inpainting'...
# remote: Enumerating objects: 350, done.
# remote: Total 350 (delta 0), reused 0 (delta 0), pack-reused 350
# Receiving objects: 100% (350/350), 130.13 MiB | 21.87 MiB/s, done.
# Resolving deltas: 100% (192/192), done.
# /content/3d-photo-inpainting
# downloading from filebox ...
# --2021-04-05 07:33:33--  https://filebox.ece.vt.edu/~jbhuang/project/3DPhoto/model/color-model.pth
# Resolving filebox.ece.vt.edu (filebox.ece.vt.edu)... 128.173.88.43
# Connecting to filebox.ece.vt.edu (filebox.ece.vt.edu)|128.173.88.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 206331633 (197M)
# Saving to: ‘color-model.pth’
#
# color-model.pth     100%[===================>] 196.77M  15.5MB/s    in 17s
#
# 2021-04-05 07:33:51 (11.4 MB/s) - ‘color-model.pth’ saved [206331633/206331633]
#
# --2021-04-05 07:33:51--  https://filebox.ece.vt.edu/~jbhuang/project/3DPhoto/model/depth-model.pth
# Resolving filebox.ece.vt.edu (filebox.ece.vt.edu)... 128.173.88.43
# Connecting to filebox.ece.vt.edu (filebox.ece.vt.edu)|128.173.88.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 206272258 (197M)
# Saving to: ‘depth-model.pth’
#
# depth-model.pth     100%[===================>] 196.72M  14.9MB/s    in 18s
#
# 2021-04-05 07:34:10 (11.0 MB/s) - ‘depth-model.pth’ saved [206272258/206272258]
#
# --2021-04-05 07:34:10--  https://filebox.ece.vt.edu/~jbhuang/project/3DPhoto/model/edge-model.pth
# Resolving filebox.ece.vt.edu (filebox.ece.vt.edu)... 128.173.88.43
# Connecting to filebox.ece.vt.edu (filebox.ece.vt.edu)|128.173.88.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45974122 (44M)
# Saving to: ‘edge-model.pth’
#
# edge-model.pth      100%[===================>]  43.84M  11.4MB/s    in 7.1s
#
# 2021-04-05 07:34:18 (6.18 MB/s) - ‘edge-model.pth’ saved [45974122/45974122]
#
# --2021-04-05 07:34:18--  https://filebox.ece.vt.edu/~jbhuang/project/3DPhoto/model/model.pt
# Resolving filebox.ece.vt.edu (filebox.ece.vt.edu)... 128.173.88.43
# Connecting to filebox.ece.vt.edu (filebox.ece.vt.edu)|128.173.88.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149751722 (143M)
# Saving to: ‘model.pt’
#
# model.pt            100%[===================>] 142.81M  15.0MB/s    in 14s
#
# 2021-04-05 07:34:33 (10.3 MB/s) - ‘model.pt’ saved [149751722/149751722]

# %% [markdown]
# - **Switch off off-screen rendering**

# %%
# !sed -i 's/offscreen_rendering: True/offscreen_rendering: False/g' argument.yml

# %% [markdown]
# - **Please upload `.jpg` files to `/content/3d-photo-inpainting-master/image/`**
#   - You can run this step multiple times to upload multiple `.jpg` files.

# %%
# %cd image
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# %cd ..
# Out:
# [Errno 2] No such file or directory: 'image'
# /content/3d-photo-inpainting/image
#      <input type="file" id="files-a3659969-7a9e-445d-8d1f-9fca466c49d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a3659969-7a9e-445d-8d1f-9fca466c49d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving DSC02721.JPG to DSC02721.JPG
# User uploaded file "DSC02721.JPG" with length 8032801 bytes
# /content/3d-photo-inpainting

# %% [markdown]
# - **Execute the 3D Photo Inpainting**
#   - Note: The 3D photo generation process usually takes about 2-3 minutes or more depending on the available computing resources.

# %%
# !python main.py --config argument.yml
# Out:
# running on device 0
#   0% 0/1 [00:00<?, ?it/s]Current Source ==>  moon
# Running depth extraction at 1617608313.1699498
# initialize
# device: cpu
# start processing
#   processing image/moon.jpg (1/1)
# torch.Size([1, 3, 384, 384])
# finished
# Start Running 3D_Photo ...
# Loading edge model at 1617608332.244887
# Loading depth model at 1617608334.0665433
# Loading rgb model at 1617608334.9145427
# Writing depth ply (and basically doing everything) at 1617608335.7083647
# Writing mesh file mesh/moon.ply ...
# Making video at 1617608542.5216105
# fov: 53.13010235415598
# Moviepy - Building video video/moon_dolly-zoom-in.mp4.
# Moviepy - Writing video video/moon_dolly-zoom-in.mp4
#
#   0% 0/1 [04:32<?, ?it/s]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   1% 2/241 [00:00<00:38,  6.17it/s, now=None]
# t:   1% 3/241 [00:00<00:37,  6.41it/s, now=None]
# t:   4% 10/241 [00:00<00:26,  8.80it/s, now=None]
# t:   7% 18/241 [00:00<00:18, 11.95it/s, now=None]
# t:  11% 27/241 [00:00<00:13, 16.09it/s, now=None]
# t:  15% 36/241 [00:00<00:09, 21.25it/s, now=None]
# t:  18% 44/241 [00:01<00:07, 27.01it/s, now=None]
# t:  21% 51/241 [00:01<00:08, 22.92it/s, now=None]
# t:  24% 57/241 [00:01<00:07, 23.27it/s, now=None]
# t:  26% 62/241 [00:01<00:07, 23.17it/s, now=None]
# t:  27% 66/241 [00:02<00:07, 22.47it/s, now=None]
# t:  29% 70/241 [00:02<00:07, 21.61it/s, now=None]
# t:  30% 73/241 [00:02<00:07, 23.02it/s, now=None]
# t:  32% 76/241 [00:02<00:07, 21.05it/s, now=None]
# t:  33% 79/241 [00:02<00:08, 19.90it/s, now=None]
# t:  34% 82/241 [00:02<00:07, 20.82it/s, now=None]
# t:  35% 85/241 [00:02<00:07, 21.48it/s, now=None]
# t:  37% 88/241 [00:03<00:06, 22.13it/s, now=None]
# t:  38% 91/241 [00:03<00:07, 20.43it/s, now=None]
# t:  39% 94/241 [00:03<00:07, 20.37it/s, now=None]
# t:  40% 97/241 [00:03<00:06, 21.09it/s, now=None]
# t:  41% 100/241 [00:03<00:06, 21.69it/s, now=None]
# t:  43% 103/241 [00:03<00:06, 20.51it/s, now=None]
# t:  44% 107/241 [00:04<00:06, 20.46it/s, now=None]
# t:  46% 111/241 [00:04<00:06, 20.54it/s, now=None]
# t:  47% 114/241 [00:04<00:05, 22.39it/s, now=None]
# t:  49% 117/241 [00:04<00:05, 23.05it/s, now=None]
# t:  50% 120/241 [00:04<00:05, 20.31it/s, now=None]
# t:  51% 123/241 [00:04<00:06, 19.18it/s, now=None]
# t:  53% 127/241 [00:05<00:05, 19.65it/s, now=None]
# t:  54% 130/241 [00:05<00:05, 20.87it/s, now=None]
# t:  55% 133/241 [00:05<00:05, 20.42it/s, now=None]
# t:  56% 136/241 [00:05<00:04, 21.04it/s, now=None]
# t:  58% 139/241 [00:05<00:05, 19.65it/s, now=None]
# t:  59% 143/241 [00:05<00:04, 19.91it/s, now=None]
# t:  61% 146/241 [00:05<00:04, 21.43it/s, now=None]
# t:  62% 149/241 [00:06<00:04, 21.63it/s, now=None]
# t:  63% 152/241 [00:06<00:04, 20.68it/s, now=None]
# t:  64% 155/241 [00:06<00:04, 19.42it/s, now=None]
# t:  66% 159/241 [00:06<00:04, 19.83it/s, now=None]
# t:  67% 162/241 [00:06<00:03, 22.02it/s, now=None]
# t:  68% 165/241 [00:06<00:03, 19.76it/s, now=None]
# t:  70% 168/241 [00:07<00:03, 20.37it/s, now=None]
# t:  71% 171/241 [00:07<00:03, 19.38it/s, now=None]
# t:  73% 175/241 [00:07<00:03, 19.68it/s, now=None]
# t:  74% 179/241 [00:07<00:03, 19.78it/s, now=None]
# t:  76% 182/241 [00:07<00:02, 21.80it/s, now=None]
# t:  77% 185/241 [00:07<00:02, 21.02it/s, now=None]
# t:  78% 188/241 [00:08<00:02, 19.95it/s, now=None]
# t:  79% 191/241 [00:08<00:02, 19.43it/s, now=None]
# t:  80% 194/241 [00:08<00:02, 21.24it/s, now=None]
# t:  82% 197/241 [00:08<00:02, 21.66it/s, now=None]
# t:  83% 200/241 [00:08<00:02, 20.26it/s, now=None]
# t:  84% 203/241 [00:08<00:01, 19.31it/s, now=None]
# t:  85% 206/241 [00:08<00:01, 20.41it/s, now=None]
# t:  87% 209/241 [00:09<00:01, 21.31it/s, now=None]
# t:  88% 212/241 [00:09<00:01, 20.75it/s, now=None]
# t:  89% 215/241 [00:09<00:01, 19.40it/s, now=None]
# t:  90% 218/241 [00:09<00:01, 20.91it/s, now=None]
# t:  92% 221/241 [00:09<00:00, 20.48it/s, now=None]
# t:  93% 224/241 [00:09<00:00, 20.41it/s, now=None]
# t:  94% 227/241 [00:09<00:00, 19.15it/s, now=None]
# t:  95% 230/241 [00:10<00:00, 21.18it/s, now=None]
# t:  97% 233/241 [00:10<00:00, 20.03it/s, now=None]
# t:  98% 236/241 [00:10<00:00, 20.85it/s, now=None]
# t:  99% 239/241 [00:10<00:00, 19.37it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/moon_dolly-zoom-in.mp4
# Moviepy - Building video video/moon_zoom-in.mp4.
# Moviepy - Writing video video/moon_zoom-in.mp4
#
#   0% 0/1 [05:23<?, ?it/s]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   4% 9/241 [00:00<00:02, 89.14it/s, now=None]
# t:   8% 20/241 [00:00<00:02, 93.45it/s, now=None]
# t:  13% 31/241 [00:00<00:02, 96.54it/s, now=None]
# t:  18% 43/241 [00:00<00:01, 100.89it/s, now=None]
# t:  22% 52/241 [00:00<00:04, 45.46it/s, now=None]
# t:  24% 59/241 [00:01<00:05, 30.63it/s, now=None]
# t:  27% 64/241 [00:01<00:06, 27.58it/s, now=None]
# t:  29% 69/241 [00:01<00:06, 24.72it/s, now=None]
# t:  30% 73/241 [00:02<00:08, 20.41it/s, now=None]
# t:  32% 76/241 [00:02<00:08, 19.78it/s, now=None]
# t:  33% 79/241 [00:02<00:08, 18.49it/s, now=None]
# t:  34% 82/241 [00:02<00:07, 20.21it/s, now=None]
# t:  35% 85/241 [00:02<00:07, 19.82it/s, now=None]
# t:  37% 88/241 [00:02<00:08, 18.59it/s, now=None]
# t:  38% 91/241 [00:03<00:08, 17.90it/s, now=None]
# t:  39% 94/241 [00:03<00:07, 18.70it/s, now=None]
# t:  40% 97/241 [00:03<00:07, 18.97it/s, now=None]
# t:  41% 99/241 [00:03<00:07, 17.82it/s, now=None]
# t:  43% 103/241 [00:03<00:07, 17.79it/s, now=None]
# t:  44% 107/241 [00:03<00:07, 18.00it/s, now=None]
# t:  46% 110/241 [00:03<00:06, 20.12it/s, now=None]
# t:  47% 113/241 [00:04<00:06, 19.45it/s, now=None]
# t:  48% 116/241 [00:04<00:06, 18.48it/s, now=None]
# t:  49% 119/241 [00:04<00:06, 17.61it/s, now=None]
# t:  51% 122/241 [00:04<00:06, 19.68it/s, now=None]
# t:  52% 125/241 [00:04<00:06, 18.84it/s, now=None]
# t:  53% 127/241 [00:04<00:07, 16.11it/s, now=None]
# t:  54% 130/241 [00:05<00:06, 18.00it/s, now=None]
# t:  55% 132/241 [00:05<00:06, 17.90it/s, now=None]
# t:  56% 135/241 [00:05<00:06, 16.94it/s, now=None]
# t:  57% 138/241 [00:05<00:05, 18.52it/s, now=None]
# t:  58% 140/241 [00:05<00:05, 17.60it/s, now=None]
# t:  59% 143/241 [00:05<00:05, 17.02it/s, now=None]
# t:  61% 147/241 [00:06<00:05, 17.53it/s, now=None]
# t:  62% 150/241 [00:06<00:04, 19.17it/s, now=None]
# t:  63% 152/241 [00:06<00:04, 18.65it/s, now=None]
# t:  64% 154/241 [00:06<00:04, 18.54it/s, now=None]
# t:  65% 156/241 [00:06<00:04, 18.06it/s, now=None]
# t:  66% 158/241 [00:06<00:04, 18.08it/s, now=None]
# t:  66% 160/241 [00:06<00:04, 17.65it/s, now=None]
# t:  68% 163/241 [00:06<00:04, 16.99it/s, now=None]
# t:  69% 166/241 [00:07<00:04, 17.77it/s, now=None]
# t:  70% 169/241 [00:07<00:03, 19.02it/s, now=None]
# t:  71% 171/241 [00:07<00:04, 16.42it/s, now=None]
# t:  73% 175/241 [00:07<00:03, 17.05it/s, now=None]
# t:  74% 178/241 [00:07<00:03, 19.28it/s, now=None]
# t:  75% 181/241 [00:07<00:03, 18.94it/s, now=None]
# t:  76% 183/241 [00:08<00:03, 15.77it/s, now=None]
# t:  78% 187/241 [00:08<00:03, 16.38it/s, now=None]
# t:  79% 190/241 [00:08<00:02, 18.44it/s, now=None]
# t:  80% 193/241 [00:08<00:02, 17.22it/s, now=None]
# t:  81% 195/241 [00:08<00:02, 16.51it/s, now=None]
# t:  83% 199/241 [00:08<00:02, 17.03it/s, now=None]
# t:  84% 202/241 [00:09<00:02, 17.61it/s, now=None]
# t:  85% 205/241 [00:09<00:01, 18.31it/s, now=None]
# t:  86% 207/241 [00:09<00:02, 16.91it/s, now=None]
# t:  88% 211/241 [00:09<00:01, 17.41it/s, now=None]
# t:  89% 214/241 [00:09<00:01, 18.53it/s, now=None]
# t:  90% 216/241 [00:09<00:01, 17.32it/s, now=None]
# t:  90% 218/241 [00:09<00:01, 17.13it/s, now=None]
# t:  91% 220/241 [00:10<00:01, 17.76it/s, now=None]
# t:  93% 223/241 [00:10<00:01, 17.64it/s, now=None]
# t:  94% 226/241 [00:10<00:00, 19.98it/s, now=None]
# t:  95% 229/241 [00:10<00:00, 19.44it/s, now=None]
# t:  96% 232/241 [00:10<00:00, 18.09it/s, now=None]
# t:  97% 234/241 [00:10<00:00, 17.78it/s, now=None]
# t:  98% 236/241 [00:10<00:00, 18.05it/s, now=None]
# t:  99% 239/241 [00:11<00:00, 17.31it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/moon_zoom-in.mp4
# Moviepy - Building video video/moon_circle.mp4.
# Moviepy - Writing video video/moon_circle.mp4
#
#   0% 0/1 [06:15<?, ?it/s]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   5% 11/241 [00:00<00:02, 100.47it/s, now=None]
# t:  10% 23/241 [00:00<00:02, 102.95it/s, now=None]
# t:  14% 34/241 [00:00<00:02, 100.90it/s, now=None]
# t:  18% 44/241 [00:00<00:02, 97.55it/s, now=None]
# t:  22% 52/241 [00:00<00:05, 37.05it/s, now=None]
# t:  24% 58/241 [00:01<00:07, 26.03it/s, now=None]
# t:  26% 63/241 [00:01<00:08, 21.52it/s, now=None]
# t:  28% 67/241 [00:01<00:08, 19.88it/s, now=None]
# t:  29% 70/241 [00:02<00:08, 19.74it/s, now=None]
# t:  30% 73/241 [00:02<00:08, 19.95it/s, now=None]
# t:  32% 76/241 [00:02<00:09, 17.89it/s, now=None]
# t:  33% 79/241 [00:02<00:09, 16.78it/s, now=None]
# t:  34% 81/241 [00:02<00:09, 16.42it/s, now=None]
# t:  35% 84/241 [00:02<00:08, 18.04it/s, now=None]
# t:  36% 86/241 [00:03<00:08, 17.35it/s, now=None]
# t:  37% 88/241 [00:03<00:09, 15.57it/s, now=None]
# t:  37% 90/241 [00:03<00:09, 15.83it/s, now=None]
# t:  38% 92/241 [00:03<00:09, 15.61it/s, now=None]
# t:  39% 94/241 [00:03<00:10, 14.68it/s, now=None]
# t:  40% 96/241 [00:03<00:09, 15.87it/s, now=None]
# t:  41% 98/241 [00:03<00:08, 16.75it/s, now=None]
# t:  41% 100/241 [00:03<00:09, 14.58it/s, now=None]
# t:  43% 103/241 [00:04<00:09, 14.52it/s, now=None]
# t:  44% 105/241 [00:04<00:08, 15.60it/s, now=None]
# t:  44% 107/241 [00:04<00:09, 14.47it/s, now=None]
# t:  46% 110/241 [00:04<00:08, 16.32it/s, now=None]
# t:  46% 112/241 [00:04<00:08, 14.82it/s, now=None]
# t:  48% 115/241 [00:04<00:08, 14.59it/s, now=None]
# t:  49% 118/241 [00:05<00:07, 15.53it/s, now=None]
# t:  50% 120/241 [00:05<00:08, 14.75it/s, now=None]
# t:  51% 122/241 [00:05<00:07, 15.90it/s, now=None]
# t:  51% 124/241 [00:05<00:07, 15.08it/s, now=None]
# t:  53% 127/241 [00:05<00:07, 14.81it/s, now=None]
# t:  54% 130/241 [00:05<00:06, 16.51it/s, now=None]
# t:  55% 132/241 [00:06<00:07, 15.25it/s, now=None]
# t:  56% 134/241 [00:06<00:06, 16.22it/s, now=None]
# t:  56% 136/241 [00:06<00:06, 15.48it/s, now=None]
# t:  57% 138/241 [00:06<00:06, 16.43it/s, now=None]
# t:  58% 140/241 [00:06<00:06, 15.73it/s, now=None]
# t:  59% 142/241 [00:06<00:06, 16.43it/s, now=None]
# t:  60% 144/241 [00:06<00:05, 16.30it/s, now=None]
# t:  61% 146/241 [00:06<00:05, 16.71it/s, now=None]
# t:  61% 148/241 [00:07<00:05, 15.71it/s, now=None]
# t:  63% 151/241 [00:07<00:05, 15.45it/s, now=None]
# t:  63% 153/241 [00:07<00:05, 16.00it/s, now=None]
# t:  64% 155/241 [00:07<00:05, 15.96it/s, now=None]
# t:  66% 158/241 [00:07<00:04, 18.10it/s, now=None]
# t:  66% 160/241 [00:07<00:04, 16.44it/s, now=None]
# t:  67% 162/241 [00:07<00:04, 17.13it/s, now=None]
# t:  68% 164/241 [00:07<00:04, 16.27it/s, now=None]
# t:  69% 167/241 [00:08<00:04, 15.66it/s, now=None]
# t:  71% 170/241 [00:08<00:03, 18.20it/s, now=None]
# t:  72% 173/241 [00:08<00:03, 17.45it/s, now=None]
# t:  73% 175/241 [00:08<00:04, 14.93it/s, now=None]
# t:  74% 179/241 [00:08<00:04, 15.47it/s, now=None]
# t:  76% 182/241 [00:08<00:03, 17.67it/s, now=None]
# t:  76% 184/241 [00:09<00:03, 15.75it/s, now=None]
# t:  77% 186/241 [00:09<00:03, 16.48it/s, now=None]
# t:  78% 188/241 [00:09<00:03, 15.52it/s, now=None]
# t:  79% 190/241 [00:09<00:03, 15.07it/s, now=None]
# t:  80% 192/241 [00:09<00:03, 15.48it/s, now=None]
# t:  80% 194/241 [00:09<00:02, 16.50it/s, now=None]
# t:  81% 196/241 [00:09<00:02, 15.96it/s, now=None]
# t:  83% 199/241 [00:10<00:02, 15.13it/s, now=None]
# t:  84% 202/241 [00:10<00:02, 15.60it/s, now=None]
# t:  85% 204/241 [00:10<00:02, 15.69it/s, now=None]
# t:  86% 207/241 [00:10<00:02, 15.45it/s, now=None]
# t:  87% 210/241 [00:10<00:01, 17.31it/s, now=None]
# t:  88% 212/241 [00:10<00:01, 15.70it/s, now=None]
# t:  89% 215/241 [00:11<00:01, 15.15it/s, now=None]
# t:  90% 218/241 [00:11<00:01, 17.71it/s, now=None]
# t:  91% 220/241 [00:11<00:01, 15.37it/s, now=None]
# t:  92% 222/241 [00:11<00:01, 16.48it/s, now=None]
# t:  93% 224/241 [00:11<00:01, 15.56it/s, now=None]
# t:  94% 227/241 [00:11<00:00, 15.47it/s, now=None]
# t:  95% 230/241 [00:11<00:00, 16.83it/s, now=None]
# t:  96% 232/241 [00:12<00:00, 17.15it/s, now=None]
# t:  97% 234/241 [00:12<00:00, 16.45it/s, now=None]
# t:  98% 236/241 [00:12<00:00, 16.36it/s, now=None]
# t:  99% 238/241 [00:12<00:00, 15.99it/s, now=None]
# t: 100% 241/241 [00:12<00:00, 17.47it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/moon_circle.mp4
# Moviepy - Building video video/moon_swing.mp4.
# Moviepy - Writing video video/moon_swing.mp4
#
#   0% 0/1 [07:08<?, ?it/s]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   4% 9/241 [00:00<00:02, 86.12it/s, now=None]
# t:   8% 19/241 [00:00<00:02, 88.65it/s, now=None]
# t:  12% 28/241 [00:00<00:02, 87.52it/s, now=None]
# t:  15% 37/241 [00:00<00:02, 88.16it/s, now=None]
# t:  19% 46/241 [00:00<00:02, 86.68it/s, now=None]
# t:  22% 54/241 [00:01<00:05, 32.01it/s, now=None]
# t:  25% 60/241 [00:01<00:06, 26.51it/s, now=None]
# t:  27% 65/241 [00:01<00:10, 17.56it/s, now=None]
# t:  29% 69/241 [00:02<00:09, 17.76it/s, now=None]
# t:  30% 72/241 [00:02<00:10, 16.86it/s, now=None]
# t:  31% 75/241 [00:02<00:08, 19.12it/s, now=None]
# t:  32% 78/241 [00:02<00:09, 18.01it/s, now=None]
# t:  34% 81/241 [00:02<00:09, 16.23it/s, now=None]
# t:  34% 83/241 [00:03<00:09, 15.89it/s, now=None]
# t:  35% 85/241 [00:03<00:09, 16.53it/s, now=None]
# t:  36% 87/241 [00:03<00:09, 16.78it/s, now=None]
# t:  37% 89/241 [00:03<00:09, 16.07it/s, now=None]
# t:  38% 92/241 [00:03<00:09, 16.05it/s, now=None]
# t:  39% 95/241 [00:03<00:08, 17.30it/s, now=None]
# t:  40% 97/241 [00:03<00:09, 15.75it/s, now=None]
# t:  41% 100/241 [00:04<00:08, 15.75it/s, now=None]
# t:  43% 103/241 [00:04<00:08, 16.29it/s, now=None]
# t:  44% 106/241 [00:04<00:07, 16.95it/s, now=None]
# t:  45% 108/241 [00:04<00:08, 16.13it/s, now=None]
# t:  46% 111/241 [00:04<00:07, 17.91it/s, now=None]
# t:  47% 113/241 [00:04<00:08, 15.37it/s, now=None]
# t:  48% 115/241 [00:05<00:08, 14.40it/s, now=None]
# t:  49% 118/241 [00:05<00:07, 16.34it/s, now=None]
# t:  50% 120/241 [00:05<00:08, 14.57it/s, now=None]
# t:  51% 122/241 [00:05<00:07, 15.64it/s, now=None]
# t:  51% 124/241 [00:05<00:07, 14.94it/s, now=None]
# t:  53% 127/241 [00:05<00:06, 16.86it/s, now=None]
# t:  54% 129/241 [00:05<00:07, 15.11it/s, now=None]
# t:  54% 131/241 [00:05<00:07, 15.09it/s, now=None]
# t:  56% 134/241 [00:06<00:06, 16.00it/s, now=None]
# t:  56% 136/241 [00:06<00:06, 15.00it/s, now=None]
# t:  58% 139/241 [00:06<00:05, 17.18it/s, now=None]
# t:  59% 141/241 [00:06<00:06, 15.71it/s, now=None]
# t:  59% 143/241 [00:06<00:06, 15.28it/s, now=None]
# t:  60% 145/241 [00:06<00:05, 16.16it/s, now=None]
# t:  61% 148/241 [00:07<00:05, 15.55it/s, now=None]
# t:  62% 150/241 [00:07<00:05, 16.08it/s, now=None]
# t:  63% 152/241 [00:07<00:05, 16.05it/s, now=None]
# t:  64% 155/241 [00:07<00:04, 17.79it/s, now=None]
# t:  65% 157/241 [00:07<00:05, 16.72it/s, now=None]
# t:  66% 159/241 [00:07<00:04, 16.98it/s, now=None]
# t:  67% 161/241 [00:07<00:04, 16.94it/s, now=None]
# t:  68% 164/241 [00:07<00:04, 15.89it/s, now=None]
# t:  70% 168/241 [00:08<00:04, 17.29it/s, now=None]
# t:  71% 171/241 [00:08<00:03, 19.03it/s, now=None]
# t:  72% 174/241 [00:08<00:03, 19.94it/s, now=None]
# t:  73% 177/241 [00:08<00:03, 18.94it/s, now=None]
# t:  75% 180/241 [00:08<00:03, 17.97it/s, now=None]
# t:  76% 183/241 [00:08<00:03, 17.98it/s, now=None]
# t:  77% 185/241 [00:09<00:03, 17.16it/s, now=None]
# t:  78% 188/241 [00:09<00:03, 16.70it/s, now=None]
# t:  79% 190/241 [00:09<00:02, 17.29it/s, now=None]
# t:  80% 192/241 [00:09<00:02, 16.73it/s, now=None]
# t:  80% 194/241 [00:09<00:02, 17.52it/s, now=None]
# t:  81% 196/241 [00:09<00:02, 16.19it/s, now=None]
# t:  83% 199/241 [00:09<00:02, 17.35it/s, now=None]
# t:  83% 201/241 [00:10<00:02, 15.96it/s, now=None]
# t:  85% 204/241 [00:10<00:02, 15.38it/s, now=None]
# t:  86% 207/241 [00:10<00:01, 17.72it/s, now=None]
# t:  87% 209/241 [00:10<00:02, 15.47it/s, now=None]
# t:  88% 211/241 [00:10<00:01, 15.57it/s, now=None]
# t:  88% 213/241 [00:10<00:01, 16.68it/s, now=None]
# t:  89% 215/241 [00:10<00:01, 14.44it/s, now=None]
# t:  90% 218/241 [00:11<00:01, 15.34it/s, now=None]
# t:  91% 220/241 [00:11<00:01, 16.00it/s, now=None]
# t:  93% 223/241 [00:11<00:00, 18.02it/s, now=None]
# t:  93% 225/241 [00:11<00:01, 15.94it/s, now=None]
# t:  94% 227/241 [00:11<00:00, 15.76it/s, now=None]
# t:  95% 229/241 [00:11<00:00, 15.86it/s, now=None]
# t:  96% 231/241 [00:11<00:00, 15.22it/s, now=None]
# t:  97% 233/241 [00:11<00:00, 15.98it/s, now=None]
# t:  98% 235/241 [00:12<00:00, 16.51it/s, now=None]
# t:  98% 237/241 [00:12<00:00, 15.78it/s, now=None]
# t: 100% 240/241 [00:12<00:00, 16.10it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/moon_swing.mp4
# 100% 1/1 [07:23<00:00, 443.03s/it]

# %% [markdown]
# - **The results are stored in the following directories**
#   - Corresponding depth map estimated by [MiDaS](https://github.com/intel-isl/MiDaS.git)
#       - E.g. ```/content/3d-photo-inpainting/depth/moon.npy```
#   - Inpainted 3D mesh
#       - E.g. ```/content/3d-photo-inpainting/mesh/moon.ply```
#   - Rendered videos with zoom-in motion
#       - E.g. ```/content/3d-photo-inpainting/video/moon_zoom-in.mp4```
#   - Rendered videos with swing motion
#       - E.g. ```/content/3d-photo-inpainting/video/moon_swing.mp4```
#   - Rendered videos with circle motion
#       - E.g. ```/content/3d-photo-inpainting/video/moon_circle.mp4```
#
#     ![](https://drive.google.com/uc?id=1xBiZAeGfhsoAsG08N5UM8-f993p0G5HF)
